# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow import keras

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, auc, ConfusionMatrixDisplay

# %%
df = pd.read_csv(r"system_state_data.csv", encoding='1251')
df.head()
# Out:
#    Температура  Давление  Вибрация  Скорость вращения  Ток Нагрузки  Состояние
# 0    79.967142  5.699678  2.527375        1118.438488      8.273013          0
# 1    73.617357  5.462317  2.898837        1327.922998      9.937593          0
# 2    81.476885  5.029815  2.445306        1417.278893     10.036034          0
# 3    90.230299  4.676532  2.784427        1877.537531     10.945261          0
# 4    72.658466  5.349112  1.674470        1611.310625      7.266283          0

# %% [markdown]
# ## Разведочный анализ датасета

# %%
df.describe()
# Out:
#        Температура     Давление     Вибрация  Скорость вращения  Ток Нагрузки  \
# count  1000.000000  1000.000000  1000.000000        1000.000000   1000.000000
# mean     75.193321     5.035418     3.004084        1496.256156      9.901453
# std       9.792159     0.498727     0.688418         205.426505      1.984760
# min      42.587327     3.529806     0.886341         914.110262      3.646592
# 25%      68.524097     4.696879     2.546400        1352.515909      8.634790
# 50%      75.253006     5.031539     2.999824        1500.036914      9.963516
# 75%      81.479439     5.364441     3.462641        1633.389082     11.278246
# max     113.527315     6.596554     5.748366        2148.618594     16.225820
#
#          Состояние
# count  1000.000000
# mean      0.409000
# std       0.684242
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       2.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Температура        1000 non-null   float64
#  1   Давление           1000 non-null   float64
#  2   Вибрация           1000 non-null   float64
#  3   Скорость вращения  1000 non-null   float64
#  4   Ток Нагрузки       1000 non-null   float64
#  5   Состояние          1000 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 47.0 KB

# %%
sns.countplot(x='Состояние', data=df)
plt.title('Распределение целевой переменной');

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(X.corr(), annot=True, cmap='coolwarm')
plt.title('Корреляционная матрица');

# %%
plt.figure(figsize=(10, 5))
scaler = MinMaxScaler()
sns.boxplot(data=scaler.fit_transform(df.drop("Состояние",axis=1))); #много выбросов

# %%
df.hist(figsize=(10,8));

# %%
X = df.drop("Состояние", axis=1)
pca = PCA(n_components=5)
X = pd.DataFrame(pca.fit_transform(X))
X["Состояние"] = df["Состояние"]

# %%
plt.figure(figsize=(10, 6))
sns.pairplot(X, hue="Состояние", palette="Set2")
plt.suptitle('Диаграмма рассеивания', size=16);

# %% [markdown]
# ## Предобработка

# %%
from sklearn.decomposition import PCA

def preprocess_data(df):
    def remove_outliers_iqr(df, column):
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    
    #выбросы
    for column in ['Температура', 'Давление', 'Вибрация', 'Скорость вращения','Ток Нагрузки']:
       df = remove_outliers_iqr(df, column)

    
    X = df.drop("Состояние", axis=1)
    y = df["Состояние"]

    #scaler = StandardScaler()
    scaler = MinMaxScaler()
    X = scaler.fit_transform(X) # мин-макс получился лучше
    
    # Применение PCA
    pca = PCA(n_components=3)
    X = pca.fit_transform(X)
    
    X_train, X_test, y_train, y_test = train_test_split(X, pd.get_dummies(y).values, test_size=0.2, random_state=42)
    
    smote = SMOTE()
    X_train, y_train = smote.fit_resample(X_train, y_train)
    
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = preprocess_data(df)

# %%
from sklearn.utils.class_weight import compute_class_weight

class_labels = np.unique(np.argmax(y_train, axis=1))
class_weights = compute_class_weight('balanced', classes=class_labels, y=np.argmax(y_train, axis=1))
class_weights_dict = {i: class_weights[i] for i in range(len(class_weights))}

print("Class weights:", class_weights_dict)
# Out:
# Class weights: {0: np.float64(1.0), 1: np.float64(1.0), 2: np.float64(1.0)}

# %% [markdown]
# ## Строим модель

# %%
model_keras = tf.keras.Sequential([
    keras.layers.Dense(16, activation='leaky_relu', input_shape=(3,)),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(8, activation='leaky_relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(8, activation='leaky_relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(3, activation='softmax')
])

model_keras.compile(optimizer = 'adam',
                    loss='categorical_crossentropy',
                    metrics=['accuracy', 'precision', 'recall'])

history = model_keras.fit(X_train, y_train, 
                          epochs=50,
                          class_weight=class_weights_dict, 
                          batch_size=32, 
                          validation_split=0.2)
# Out:
# Epoch 1/50
# C:\Dev\Jupyter\dist\pyenv3.12.7-win64\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4356 - loss: 1.2017 - precision: 0.4479 - recall: 0.1785 - val_accuracy: 0.0000e+00 - val_loss: 1.1885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4435 - loss: 1.1628 - precision: 0.4659 - recall: 0.1993 - val_accuracy: 0.0000e+00 - val_loss: 1.2590 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4943 - loss: 1.0838 - precision: 0.5105 - recall: 0.2274 - val_accuracy: 0.0000e+00 - val_loss: 1.3149 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5107 - loss: 1.0685 - precision: 0.5645 - recall: 0.2305 - val_accuracy: 0.0000e+00 - val_loss: 1.3458 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5194 - loss: 1.0582 - precision: 0.5296 - recall: 0.2568 - val_accuracy: 0.0000e+00 - val_loss: 1.3696 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5261 - loss: 1.0399 - precision: 0.5627 - recall: 0.2473 - val_accuracy: 0.0000e+00 - val_loss: 1.3860 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5169 - loss: 1.0326 - precision: 0.5655 - recall: 0.2718 - val_accuracy: 0.0000e+00 - val_loss: 1.4006 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5088 - loss: 1.0342 - precision: 0.5419 - recall: 0.2632 - val_accuracy: 0.0000e+00 - val_loss: 1.4238 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5208 - loss: 1.0152 - precision: 0.5577 - recall: 0.2689 - val_accuracy: 0.0000e+00 - val_loss: 1.4579 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4968 - loss: 1.0134 - precision: 0.5920 - recall: 0.3079 - val_accuracy: 0.0000e+00 - val_loss: 1.4861 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5150 - loss: 1.0077 - precision: 0.5807 - recall: 0.2728 - val_accuracy: 0.0000e+00 - val_loss: 1.5061 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5184 - loss: 1.0160 - precision: 0.5507 - recall: 0.2861 - val_accuracy: 0.0000e+00 - val_loss: 1.5217 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5293 - loss: 0.9925 - precision: 0.6128 - recall: 0.3412 - val_accuracy: 0.0000e+00 - val_loss: 1.5528 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5411 - loss: 0.9892 - precision: 0.5830 - recall: 0.3190 - val_accuracy: 0.0000e+00 - val_loss: 1.5759 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5421 - loss: 0.9886 - precision: 0.5805 - recall: 0.3327 - val_accuracy: 0.0000e+00 - val_loss: 1.5913 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5250 - loss: 0.9864 - precision: 0.5684 - recall: 0.3163 - val_accuracy: 0.0000e+00 - val_loss: 1.6034 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.
50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5447 - loss: 0.9542 - precision: 0.6057 - recall: 0.3857 - val_accuracy: 0.0000e+00 - val_loss: 1.6775 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 41/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5335 - loss: 0.9715 - precision: 0.5911 - recall: 0.3578 - val_accuracy: 0.0000e+00 - val_loss: 1.6832 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 42/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5566 - loss: 0.9386 - precision: 0.6289 - recall: 0.3870 - val_accuracy: 0.0000e+00 - val_loss: 1.6588 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 43/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5726 - loss: 0.9311 - precision: 0.6309 - recall: 0.4220 - val_accuracy: 0.0000e+00 - val_loss: 1.7525 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 44/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5354 - loss: 0.9575 - precision: 0.5771 - recall: 0.3735 - val_accuracy: 0.0000e+00 - val_loss: 1.7318 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 45/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5491 - loss: 0.9469 - precision: 0.6005 - recall: 0.4291 - val_accuracy: 0.0000e+00 - val_loss: 1.6976 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 46/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5442 - loss: 0.9568 - precision: 0.5797 - recall: 0.4308 - val_accuracy: 0.0000e+00 - val_loss: 1.7871 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 47/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5597 - loss: 0.9465 - precision: 0.6194 - recall: 0.4158 - val_accuracy: 0.0000e+00 - val_loss: 1.7605 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 48/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5804 - loss: 0.9215 - precision: 0.6341 - recall: 0.4502 - val_accuracy: 0.0000e+00 - val_loss: 1.6796 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 49/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5591 - loss: 0.9412 - precision: 0.5887 - recall: 0.4358 - val_accuracy: 0.0000e+00 - val_loss: 1.5744 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 50/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5462 - loss: 0.9471 - precision: 0.5930 - recall: 0.4240 - val_accuracy: 0.0000e+00 - val_loss: 1.6719 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
test_loss, test_accuracy, test_prec, test_recall = model_keras.evaluate(X_test, y_test)
print(f'Test accuracy: {test_accuracy}')
print(f'Test loss: {test_loss}')
print(f'Test precision: {test_prec}')
print(f'Test recall: {test_recall}')
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4295 - loss: 1.0780 - precision: 0.4410 - recall: 0.3345
# Test accuracy: 0.453125
# Test loss: 1.064477801322937
# Test precision: 0.4503311216831207
# Test recall: 0.3541666567325592

# %% [markdown]
# ## Оценка модели

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18, 10))

plt.subplot(2, 2, 1) 
plt.plot(history.history['loss'], label='Обучающая loss')
plt.plot(history.history['val_loss'], label='Валидационная loss')
plt.title('Loss')
plt.xlabel('Эпохи')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(history.history['accuracy'], label='Обучающая accuracy')
plt.plot(history.history['val_accuracy'], label='Валидационная accuracy')
plt.title('Accuracy')
plt.xlabel('Эпохи')
plt.ylabel('Accuracy')
plt.legend()

plt.ylim(0,1.01)

plt.subplot(2, 2, 3)
plt.plot(history.history['recall'], label='Recall')
plt.plot(history.history['val_recall'], label='Val Recall')
plt.title('Recall')
plt.xlabel('Эпохи')
plt.ylabel('Recall')
plt.legend()

plt.ylim(0,1.01)

plt.subplot(2, 2, 4)
plt.plot(history.history['precision'], label='Precision')
plt.plot(history.history['val_precision'], label='Val Precision')
plt.title('Precision')
plt.xlabel('Эпохи')
plt.ylabel('Precision')
plt.legend()

plt.ylim(0,1.01)

plt.tight_layout()  # автоматически подгоняет подграфики
plt.show()

# %%
y_score = model_keras.predict(X_test)

y_pred = np.argmax(y_score, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1, 2])
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix');
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

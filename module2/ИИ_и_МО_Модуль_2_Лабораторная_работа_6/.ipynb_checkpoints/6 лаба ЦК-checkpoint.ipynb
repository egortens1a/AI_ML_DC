# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -q spacy
# !pip install -q
# Out:
# ERROR: You must give at least one requirement to install (see "pip help install")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import string

import tensorflow as tf
import tensorflow.keras as keras
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN, LSTM, Dense, Bidirectional, Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.callbacks import EarlyStopping

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
import nltk# ПОПРОБОВАТЬ RAZDEL

nltk.download('stopwords')
# Загрузка ресурса punkt
nltk.download('punkt_tab')

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.snowball import SnowballStemmer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
df = pd.read_csv("3rd_dataset.csv")
#df = pd.read_csv(r'/content/drive/MyDrive/ML-edu/AI_ML_DC/module2/ИИ_и_МО_Модуль_2_Лабораторная_работа_6/3rd_dataset.csv')

# %%
df['category'].unique()
# Out:
# array(['Автоматика. Вычислительная техника', 'Астрономия', 'Биология',
#        'Биотрехнология', 'Внешняя торговля'], dtype=object)

# %%
#raw_ru = 'АЛГОРИТМ МАРКИРОВАНИЯ ТЕКСТОВЫХ ДОКУМЕНТОВ НА ОСНОВЕ ИЗМЕНЕНИЯ ИНТЕРВАЛОВ МЕЖДУ СЛОВАМИ, ОБЕСПЕЧИВАЮЩИЙ УСТОЙЧИВОСТЬ К ПРЕОБРАЗОВАНИЮ ФОРМАТА'
#nlp = spacy.load('ru_core_news_lg')
#spacy_results = nlp(raw_ru)

# %%
df
# Out:
#                                                  title  \
# 0    СРАВНЕНИЕ СИСТЕМЫ ОБНАРУЖЕНИЯ ВТОРЖЕНИЙ НА ОСН...
# 1    ОПРЕДЕЛЕНИЕ ВЛИЯТЕЛЬНЫХ ПОЛЬЗОВАТЕЛЕЙ СОЦИАЛЬН...
# 2    АЛГОРИТМ МАРКИРОВАНИЯ ТЕКСТОВЫХ ДОКУМЕНТОВ НА ...
# 3    СРЕДСТВА ЗАХВАТА И ОБРАБОТКИ ВЫСОКОСКОРОСТНОГО...
# 4    ИННОВАЦИОННЫЙ ПОДХОД К АВТОМАТИЗИРОВАННОЙ ФОТО...
# ..                                                 ...
# 189  ЭКОНОМИЧЕСКИЕ И ТЕХНОЛОГИЧЕСКИЕ ФАКТОРЫ РАЗВИТ...
# 190  ПРОБЛЕМЫ УЧАСТИЯ РОССИИ В ОСВОЕНИИ НЕФТЕГАЗОВЫ...
# 191  РОССИЙСКИЕ ТРАНСНАЦИОНАЛЬНЫЕ КОРПОРАЦИИ НА МЕЖ...
# 192                   ВНЕШНЯЯ ТОРГОВЛЯ РОССИИ УСЛУГАМИ
# 193  ДИАГНОСТИКА И ИДЕНТИФИКАЦИЯ НЕФТИ И НЕФТЕПРОДУ...
#
#                                category
# 0    Автоматика. Вычислительная техника
# 1    Автоматика. Вычислительная техника
# 2    Автоматика. Вычислительная техника
# 3    Автоматика. Вычислительная техника
# 4    Автоматика. Вычислительная техника
# ..                                  ...
# 189                    Внешняя торговля
# 190                    Внешняя торговля
# 191                    Внешняя торговля
# 192                    Внешняя торговля
# 193                    Внешняя торговля
#
# [194 rows x 2 columns]

# %%
plt.figure(figsize=(16,8))
sns.histplot(df['category'])
# Out:
# <Axes: xlabel='category', ylabel='Count'>

# %%
def preprocess_y(y, label_encoder=None):
      if label_encoder is None:
        label_encoder = LabelEncoder().fit(y)

      y_encoded = label_encoder.transform(y)

      return y_encoded, label_encoder

def preprocess_X(X, tokenizer=None):
    # Разделение на обучающую и тестовую выборки
    new_X = []
    for i,text in enumerate(X):
        text = text.translate(str.maketrans('', '', string.punctuation)).lower()
        tokens = word_tokenize(text) #токенизация

        stop_words = set(stopwords.words('russian'))
        tokens = [word for word in tokens if word not in stop_words] #убираем стоп слова

        stemmer = SnowballStemmer("russian")
        tokens = [stemmer.stem(word) for word in tokens] # стемминг

        new_X.append(' '.join(tokens))

    if tokenizer is None:
      tokenizer = Tokenizer()
      tokenizer.fit_on_texts(new_X)

    X_seq = tokenizer.texts_to_sequences(new_X)

    max_length = max(len(x) for x in X_seq)
    X_pad = pad_sequences(X_seq, maxlen=max_length, padding='post')

    return X_pad, max_length, tokenizer

# %%
X_train, X_test, y_train, y_test = train_test_split(df['title'], df['category'], test_size=0.2, random_state=42)

# %%
X_train, max_length, tokenizer = preprocess_X(X_train)
y_train, label_encoder = preprocess_y(y_train)

# %%
X_test_proc, _, _ = preprocess_X(X_test, tokenizer=tokenizer)
y_test_proc, l = preprocess_y(y_test, label_encoder=label_encoder)

# %%
from sklearn.utils.class_weight import compute_class_weight

class_labels = np.unique(y_train)
class_weights = compute_class_weight('balanced', classes=class_labels, y=y_train)
class_weights_dict = {i: class_weights[i] for i in range(len(class_weights))}

print("Class weights:", class_weights_dict)
# Out:
# Class weights: {0: np.float64(1.3478260869565217), 1: np.float64(1.1481481481481481), 2: np.float64(1.7222222222222223), 3: np.float64(0.7209302325581395), 4: np.float64(0.7045454545454546)}

# %%
# 5. Создание модели RNN
model = Sequential(
    [
        Embedding(input_dim=1000, output_dim=128, input_length=max_length),
        Bidirectional(LSTM(128, activation='tanh')),
        Dropout(0.4),
        Dense(5, activation='softmax')
    ]
)

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])


early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
# 6. Обучение модели
history = model.fit(X_train, y_train,
                    epochs=30,
                    batch_size=16,
                    class_weight=class_weights_dict,
                    callbacks=early_stopping,
                    validation_split=0.2)

# 7. Оценка модели
loss, accuracy = model.evaluate(X_test_proc, y_test_proc)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Epoch 1/30
# C:\Dev\Jupyter\dist\pyenv3.12.7-win64\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.2044 - loss: 1.7395 - val_accuracy: 0.0645 - val_loss: 1.6432
# Epoch 2/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.2119 - loss: 1.5915 - val_accuracy: 0.3548 - val_loss: 1.5929
# Epoch 3/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4818 - loss: 1.6182 - val_accuracy: 0.3226 - val_loss: 1.5858
# Epoch 4/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6488 - loss: 1.5797 - val_accuracy: 0.3548 - val_loss: 1.5647
# Epoch 5/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5874 - loss: 1.3932 - val_accuracy: 0.1935 - val_loss: 1.5935
# Epoch 6/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6132 - loss: 1.2773 - val_accuracy: 0.3226 - val_loss: 1.6938
# Epoch 7/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5285 - loss: 1.2184 - val_accuracy: 0.1935 - val_loss: 1.5640
# Epoch 8/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7745 - loss: 0.9528 - val_accuracy: 0.3871 - val_loss: 1.4631
# Epoch 9/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8246 - loss: 0.6587 - val_accuracy: 0.5806 - val_loss: 1.2107
# Epoch 10/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9317 - loss: 0.3577 - val_accuracy: 0.5161 - val_loss: 1.2630
# Epoch 11/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9362 - loss: 0.2045 - val_accuracy: 0.6774 - val_loss: 0.9900
# Epoch 12/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9982 - loss: 0.0971 - val_accuracy: 0.6452 - val_loss: 0.9706
# Epoch 13/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9947 - loss: 0.0545 - val_accuracy: 0.5484 - val_loss: 1.5696
# Epoch 14/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9827 - loss: 0.0471 - val_accuracy: 0.6452 - val_loss: 1.2173
# Epoch 15/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0423 - val_accuracy: 0.5806 - val_loss: 1.2950
# Epoch 16/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0365 - val_accuracy: 0.6774 - val_loss: 1.0847
# Epoch 17/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 0.7097 - val_loss: 1.2097
# Epoch 18/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0169 - val_accuracy: 0.6452 - val_loss: 1.4675
# Epoch 19/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.6774 - val_loss: 1.4338
# Epoch 20/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.6774 - val_loss: 1.3673
# Epoch 21/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.6129 - val_loss: 1.6584
# Epoch 22/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.6452 - val_loss: 1.3725
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6803 - loss: 1.0643
# Accuracy: 69.23%

# %%
plt.figure(figsize=(18, 10))

plt.subplot(2, 2, 1)
plt.plot(history.history['loss'], label='Обучающая loss')
plt.plot(history.history['val_loss'], label='Валидационная loss')
plt.title('Loss')
plt.xlabel('Эпохи')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(history.history['accuracy'], label='Accuracy')
plt.plot(history.history['val_accuracy'], label='Val accuracy')
plt.title('Accuracy')
plt.xlabel('Эпохи')
plt.ylabel('Accuracy')
plt.legend()

plt.ylim(0,1.01)

plt.tight_layout()  # автоматически подгоняет подграфики
plt.show()

# %%
test,_ ,_ = preprocess_X(['река бобер гриб дерево дождь здоровье'], tokenizer=tokenizer)

predicted = model.predict(test)
predicted_category = label_encoder.inverse_transform([predicted.argmax()])

print(f'Predicted category: {predicted_category[0]}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# Predicted category: Биология

# %%
test,_ ,_ = preprocess_X(['солнце марс система планета звезда'], tokenizer=tokenizer)

predicted = model.predict(test)
predicted_category = label_encoder.inverse_transform([predicted.argmax()])

print(f'Predicted category: {predicted_category[0]}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted category: Астрономия

# %%
label_encoder.classes_
# Out:
# array(['Автоматика. Вычислительная техника', 'Астрономия', 'Биология',
#        'Биотрехнология', 'Внешняя торговля'], dtype=object)

# %%
predicted = model.predict(X_test_proc)
for text, pred, y_true in zip(X_test, predicted, y_test):
  predicted_category = label_encoder.inverse_transform([pred.argmax()])
  f = ('+' if y_true==predicted_category else '-')
  print(y_true)
  print(f'{f} {text} =:= {predicted_category[0]}')
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Биотрехнология
# + ЭКСПЕРИМЕНТАЛЬНОЕ ОПРЕДЕЛЕНИЕ ПАРАМЕТРОВ ХВОЙНОГО ЛЕЧЕБНОГО ЭКСТРАКТА, НЕОБХОДИМЫХ ДЛЯ ОПТИМИЗАЦИИ ПРОЦЕССА КОНЦЕНТРИРОВАНИЯ В РОТОРНО-ВАКУУМНОМ ПЛЕНОЧНОМ ИСПАРИТЕЛЕ =:= Биотрехнология
# Автоматика. Вычислительная техника
# + ИНФОРМАЦИОННАЯ ТЕХНОЛОГИЯ ОБРАБОТКИ ДАННЫХ ДЗЗ ДЛЯ ОЦЕНКИ АРЕАЛОВ РАСТЕНИЙ =:= Автоматика. Вычислительная техника
# Внешняя торговля
# - ОЦЕНКА НАЛИЧИЯ ОСНОВНЫХ ФОНДОВ В РФ ПО УЧЕТНОЙ СТОИМОСТИ С 2000 ПО 2014 ГОД =:= Астрономия
# Биотрехнология
# - ГЕН ROLC АГРОБАКТЕРИЙ: НА ПУТИ К ПОНИМАНИЮ ФУНКЦИИ =:= Астрономия
# Биология
# - АНТАГОНИСТИЧЕСКИЙ ПОТЕНЦИАЛ СИБИРСКИХ ШТАММОВ BACILLUS SPP. В ОТНОШЕНИИ ВОЗБУДИТЕЛЕЙ БОЛЕЗНЕЙ ЖИВОТНЫХ И РАСТЕНИЙ =:= Астрономия
# Внешняя торговля
# + ПРАВИЛА ВСЕМИРНОЙ ТОРГОВОЙ ОРГАНИЗАЦИИ И ПРОТЕКЦИОНИЗМ В ОБЛАСТИ ВОЗОБНОВЛЯЕМЫХ ИСТОЧНИКОВ ЭНЕРГИИ" =:= Внешняя торговля
# Астрономия
# + МАГНИТНЫЕ СР-ЗВЕЗДЫ ГЛАВНОЙ ПОСЛЕДОВАТЕЛЬНОСТИ П. ФИЗИЧЕСКИЕ ПАРАМЕТРЫ И ХИМИЧЕСКИЙ СОСТАВ АТМОСФЕР =:= Астрономия
# Автоматика. Вычислительная техника
# + АЛГЕБРАИЧЕСКИЕ МОДЕЛИ И МЕТОДЫ КОМПЬЮТЕРНОЙ ОБРАБОТКИ ИЗОБРАЖЕНИЙ. ЧАСТЬ 1. МУЛЬТИПЛЕТНЫЕ МОДЕЛИ МНОГОКАНАЛЬНЫХ ИЗОБРАЖЕНИЙ =:= Автоматика. Вычислительная техника
# Биотрехнология
# + ФИТОХИМИЧЕСКИЙ АНАЛИЗ БИОТЕХНОЛОГИЧЕСКОГО СЫРЬЯ ПРЕДСТАВИТЕЛЕЙ РОДА POTENTILLA L =:= Биотрехнология
# Биотрехнология
# + ПОЛУЧЕНИЕ КЛЕТОЧНОЙ КУЛЬТУРЫ ИМБИРЯ =:= Биотрехнология
# Внешняя торговля
# + ТАМОЖЕННОЕ СОТРУДНИЧЕСТВО СТРАН - ЧЛЕНОВ ЕАЭС: НОВЫЕ ГОРИЗОНТЫ =:= Внешняя торговля
# Автоматика. Вычислительная техника
# + ЛОКАЛИЗАЦИЯ ЧЕЛОВЕКА В КАДРЕ ВИДЕОПОТОКА С ИСПОЛЬЗОВАНИЕМ АЛГОРИТМА НА ОСНОВЕ РАСТУЩЕГО НЕЙРОННОГО ГАЗА И НЕЧЁТКОГО ВЫВОДА =:= Автоматика. Вычислительная техника
# Биология
# + НОВЫЕ НАХОДКИ НЕМОРАЛЬНЫХ ВИДОВ НАСЕКОМЫХ ИЗ ОТРЯДОВ DIPTERA, COLEOPTERA, NEUROPTERA, MECOPTERA, LEPIDOPTERA В ПРИАРГУНЬЕ (ЧИТИНСКАЯ ОБЛАСТЬ) И ИХ ВОЗМОЖНОЕ ЗООГЕОГРАФИЧЕСКОЕ ЗНАЧЕНИЕ =:= Биология
# Автоматика. Вычислительная техника
# + СОВРЕМЕННЫЕ МЕТОДЫ ОБЕСПЕЧЕНИЯ ЦЕЛОСТНОСТИ ДАННЫХ В ПРОТОКОЛАХ УПРАВЛЕНИЯ КИБЕРФИЗИЧЕСКИХ СИСТЕМ =:= Автоматика. Вычислительная техника
# Внешняя торговля
# + ТАМОЖЕННОЕ РЕГУЛИРОВАНИЕ ПЕРЕМЕЩЕНИЯ ЛЕГКО-ВЫХ АВТОМОБИЛЕЙ ФИЗИЧЕСКИМИ ЛИЦАМИ ЧЕРЕЗ ТАМО-ЖЕННУЮ ГРАНИЦУ ТАМОЖЕННОГО СОЮЗА =:= Внешняя торговля
# Биотрехнология
# + ОСОБЕННОСТИ ПРОВЕДЕНИЯ ПОЛЕВЫХ РАБОТ ПРИ ИЗУЧЕНИИ ХВОЙНЫХ ДРЕВОСТОЕВ ЕСТЕСТВЕННОГО ПРОИСХОЖДЕНИЯ =:= Биотрехнология
# Биология
# - СТРАТЕГИЯ БОРЬБЫ С ВИРУСНОЙ ДИАРЕЕЙ – БОЛЕЗНЬЮ СЛИЗИСТЫХ КРУПНОГО РОГАТОГО СКОТА В ЖИВОТНОВОДЧЕСКИХ ХОЗЯЙСТВАХ РОССИЙСКОЙ ФЕДЕРАЦИИ =:= Биотрехнология
# Биотрехнология
# + БИОКОНВЕРСИЯ ВТОРИЧНЫХ ПРОДУКТОВ ПЕРЕРАБОТКИ ЗЕРНА ТРИТИКАЛЕ НА КРАХМАЛ С ИСПОЛЬЗОВАНИЕМ ГРИБА PLEUROTUS OSTREATUS =:= Биотрехнология
# Внешняя торговля
# + РОССИЙСКИЕ ТРАНСНАЦИОНАЛЬНЫЕ КОРПОРАЦИИ НА МЕЖДУНАРОДНЫХ РЫНКАХ ТОВАРОВ И УСЛУГ =:= Внешняя торговля
# Биотрехнология
# - АВТОМАТИЗИРОВАННАЯ СИСТЕМА ОЦЕНКИ ПРОЛИФЕРАТИВНОЙ АКТИВНОСТИ ЭУКАРИОТИЧЕСКИХ КЛЕТОК В ТОКСИКОЛОГИЧЕСКИХ ИССЛЕДОВАНИЯХ IN VITRO =:= Астрономия
# Биотрехнология
# - АДДИТИВНОСТЬ СТАБИЛИЗИРУЮЩЕГО ЭФФЕКТА ЕДИНИЧНЫХ АМИНОКИСЛОТНЫХ ЗАМЕН В ТРОЙНЫХ МУТАНТАХ РЕКОМБИНАНТНОЙ ФОРМИАТДЕГИДРОГЕНАЗЫ ИЗ СОИ GLYCINE MAX =:= Астрономия
# Внешняя торговля
# - АВТОМАТИЧЕСКОЕ ЛИЦЕНЗИРОВАНИЕ (НАБЛЮДЕНИЕ) ЭКСПОРТА/ИМПОРТА ТОВАРОВ =:= Астрономия
# Биология
# - ЭКСПЕРИМЕНТАЛЬНОЕ ОБОСНОВАНИЕ ВОЗМОЖНОСТИ ПОЛУЧЕНИЯ КОНЦЕНТРАТА МИКРОБНЫХ КЛЕТОК ШТАММА YERSINIA PESTIS EV МЕТОДОМ МИКРОФИЛЬТРАЦИИ =:= Астрономия
# Астрономия
# + МОДЕЛЬ ПЕРЕМЕЖАЕМОСТИ ГЛОБАЛЬНЫХ МИНИМУМОВ И МАКСИМУМОВ В СОЛНЕЧНОМ ДИНАМО =:= Астрономия
# Внешняя торговля
# + О НЕКОТОРЫХ АСПЕКТАХ ПРИМЕНЕНИЯ ТЕХНОЛОГИИ УДАЛЕННОГО ВЫПУСКА ТОВАРОВ НА СОВРЕМЕННОМ ЭТАПЕ =:= Внешняя торговля
# Биотрехнология
# + МЕТОДИЧЕСКИЕ ПОДХОДЫ К ВАЛИДАЦИИ ТЕХНОЛОГИЧЕСКИХ ПРОЦЕССОВ ПОЛУЧЕНИЯ ТЕРАПЕВТИЧЕСКИХ РЕКОМБИНАТНЫХ БЕЛКОВ НА ОСНОВЕ КОНЦЕПЦИИ "QUALITY BY DESIGN" =:= Биотрехнология
# Биология
# - СОДЕРЖАНИЕ ТЯЖЕЛЫХ МЕТАЛЛОВ В МЫШЕЧНОЙ ТКАНИ РЫБ ИЗ ВОДОЕМОВ БАССЕЙНА РЕКИ ОБИ =:= Астрономия
# Биотрехнология
# + НОВЫЕ ИНТРОГРЕССИВНЫЕ ФОРМЫ КУЛЬТУРНОГО ЯЧМЕНЯ, ПОЛУЧЕННЫЕ НА ОСНОВЕ МЕЖВИДОВЫХ ГИБРИДОВ HORDEUM VULGARE L. × HORDEUM BULBOSUM L =:= Биотрехнология
# Астрономия
# + ИССЛЕДОВАНИЕ ДИНАМИКИ ОБЛАСТИ ОРБИТАЛЬНЫХ РЕЗОНАНСОВ ВЫСОКИХ ПОРЯДКОВ =:= Астрономия
# Биотрехнология
# + ИСПОЛЬЗОВАНИЕ МЕТОДОВ МОЛЕКУЛЯРНОЙ ЦИТОГЕНЕТИКИ В ИССЛЕДОВАНИЯХ ОТДАЛЕННЫХ ГИБРИДОВ КАРТОФЕЛЯ =:= Биотрехнология
# Биотрехнология
# - АНАЛИЗ ЭФФЕКТИВНОСТИ ДЕЗИНФИЦИРУЮЩИХ СРЕДСТВ КОМПАНИИ"БЕЛАСЕПТИКА" =:= Астрономия
# Биология
# - СОДЕРЖАНИЕ НЕКОТОРЫХ ТЯЖЕЛЫХ МЕТАЛЛОВ В РАСТИТЕЛЬНОСТИ ПОЛЕВЫХ И ЛУГОВЫХ АГРОФИТОЦЕНОЗОВ В УСЛОВИЯХ ТЕХНОГЕННОГО ЗАГРЯЗНЕНИЯ ПОЧВЕННОГО ПОКРОВА =:= Биотрехнология
# Автоматика. Вычислительная техника
# + ВЫДЕЛЕНИЕ КОНТУРОВ НА ИЗОБРАЖЕНИЯХ С ПОМОЩЬЮ АЛГОРИТМА КЛАСТЕРИЗАЦИИ =:= Автоматика. Вычислительная техника
# Внешняя торговля
# + РЕАЛИЗАЦИЯ КОНЦЕПЦИИ "ЕДИНОГО ОКНА" В ЕВРОПЕЙСКОМ СОЮЗЕ И СТРАНАХ АЗИАТСКО-ТИХООКЕАНСКОГО РЕГИОНА: ОРГАНИЗАЦИОННЫЙ И ФИНАНСОВЫЙ АСПЕКТЫ =:= Внешняя торговля
# Биотрехнология
# + ЖИВЫЕ СИСТЕМЫ В РОССИИ: ВЗГЛЯД СКВОЗЬ ПРИЗМУ НАУЧНЫХ ПУБЛИКАЦИЙ =:= Биотрехнология
# Внешняя торговля
# + АНАЛИЗ КОРРЕКТИРОВКИ ТАМОЖЕННОЙ СТОИМОСТИ ТОВАРОВ В ЗОНЕ ДЕЯТЕЛЬНОСТИ ЧЕЛЯБИНСКОЙ ТАМОЖНИ ЗА ПЕРИОД 2010-2016 ГГ =:= Внешняя торговля
# Автоматика. Вычислительная техника
# + АЛГОРИТМЫ РАСПОЗНАВАНИЯ РУКОПИСНЫХ СИМВОЛОВ НА ОСНОВЕ ПОСТРОЕНИЯ СТРУКТУРНЫХ МОДЕЛЕЙ =:= Автоматика. Вычислительная техника
# Внешняя торговля
# + АНАЛИЗ ПРИМЕНЕНИЯ СИСТЕМЫ УПРАВЛЕНИЯ РИСКАМИ ПРИ ПРОВЕДЕНИИ ТАМОЖЕННОГО КОНТРОЛЯ =:= Внешняя торговля
# Биология
# - ЭПИГЕНЕТИКА СЕГОДНЯ И ЗАВТРА =:= Астрономия

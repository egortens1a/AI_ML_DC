# %%
import pandas as pd
from sklearn.datasets import fetch_openml

# Загрузка данных
data = fetch_openml(name="adult", version=2, as_frame=True)
X = data.data
y = (data.target == '>50K').astype(int)  # Бинарная целевая переменная

# Объединим признаки и целевую переменную в один DataFrame
df = pd.concat([X, y.rename('income')], axis=1)

# %%
df['age_binned'] = pd.cut(df['age'], bins=5, labels=False)

# %%
from CHAID import Tree

# Укажем типы признаков в виде словаря {'признак': 'тип'}
variable_types = {
    'age': 'nominal',  # Предполагаем, что age уже преобразован в категории
    'workclass': 'nominal',
    'education': 'nominal',
    'marital-status': 'nominal',
    'occupation': 'nominal',
    'relationship': 'nominal',
    'race': 'nominal',
    'sex': 'nominal',
    'native-country': 'nominal',
    'hours-per-week': 'nominal'  # Должен быть предварительно преобразован в категории
}

# Построение дерева
tree = Tree.from_pandas_df(
    df, 
    independent_variable_types_dict=variable_types,  # Исправленный параметр
    dep_variable='income',
    max_depth=5,
    min_parent_node_size=100
)

# Визуализация дерева
tree.print_tree()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 18
#       4 variable_types = {
#       5     'age_binned': 'nominal',
#       6     'workclass': 'nominal',
#    (...)
#      14     'hours-per-week': 'nominal'  # Предварительно нужно преобразовать в категории
#      15 }
#      17 # Построение дерева
# ---> 18 tree = Tree.from_pandas_df(
#      19     df,
#      20     variable_types,
#      21     d_variable='income',
#      22     dep_variable_type=variable_types,
#      23     max_depth=5,  # Ограничим глубину для интерпретируемости
#      24     min_parent_node_size=100  # Минимальный размер узла для разделения
#      25 )
#      27 # Визуализация дерева
#      28 tree.print_tree()
#
# File E:\DEV\Jupyter\dist\pyenv3.12.7-win64\Lib\site-packages\CHAID\tree.py:174, in Tree.from_pandas_df(df, i_variables, d_variable, alpha_merge, max_depth, min_parent_node_size, min_child_node_size, split_threshold, weight, dep_variable_type, is_exhaustive, max_splits)
#     172 dep_values = df[d_variable].values
#     173 weights = df[weight] if weight is not None else None
# --> 174 return Tree.from_numpy(ind_values, dep_values, alpha_merge, max_depth, min_parent_node_size,
#     175             min_child_node_size, list(ind_df.columns.values), split_threshold, weights,
#     176             list(i_variables.values()), dep_variable_type, is_exhaustive, max_splits)
#
# File E:\DEV\Jupyter\dist\pyenv3.12.7-win64\Lib\site-packages\CHAID\tree.py:113, in Tree.from_numpy(ndarr, arr, alpha_merge, max_depth, min_parent_node_size, min_child_node_size, split_titles, split_threshold, weights, variable_types, dep_variable_type, is_exhaustive, max_splits)
#     111     observed = ContinuousColumn(arr, weights=weights)
#     112 else:
# --> 113     raise NotImplementedError('Unknown dependent variable type ' + dep_variable_type)
#     114 config = { 'alpha_merge': alpha_merge, 'max_depth': max_depth, 'min_parent_node_size': min_parent_node_size,
#     115            'min_child_node_size': min_child_node_size, 'max_splits': max_splits,
#     116            'split_threshold': split_threshold, 'is_exhaustive': is_exhaustive, }
#     117 return Tree(vectorised_array, observed, config)
#
# TypeError: can only concatenate str (not "dict") to str

# %%
from sklearn.model_selection import train_test_split

# Разделение данных
train_df, test_df = train_test_split(df, test_size=0.3, random_state=42)

# Построение дерева на train
train_tree = Tree.from_pandas_df(train_df, variable_types, 'income', max_depth=5)

# Предсказание на test
def predict(tree, row):
    node = tree.tree_store[0]
    while node.split is not None:
        col = node.split.column
        val = row[col]
        for i, group in enumerate(node.split.groups):
            if val in group:
                node = tree.tree_store[node.children[i]]
                break
    return max(node.members.items(), key=lambda x: x[1])[0]

test_df['predicted'] = test_df.apply(lambda x: predict(train_tree, x), axis=1)
accuracy = (test_df['predicted'] == test_df['income']).mean()
print(f"Accuracy: {accuracy:.2f}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 21
#      18                 break
#      19     return max(node.members.items(), key=lambda x: x[1])[0]
# ---> 21 test_df['predicted'] = test_df.apply(lambda x: predict(train_tree, x), axis=1)
#      22 accuracy = (test_df['predicted'] == test_df['income']).mean()
#      23 print(f"Accuracy: {accuracy:.2f}")
#
# File E:\DEV\Jupyter\dist\pyenv3.12.7-win64\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File E:\DEV\Jupyter\dist\pyenv3.12.7-win64\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File E:\DEV\Jupyter\dist\pyenv3.12.7-win64\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File E:\DEV\Jupyter\dist\pyenv3.12.7-win64\Lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[19], line 21, in <lambda>(x)
#      18                 break
#      19     return max(node.members.items(), key=lambda x: x[1])[0]
# ---> 21 test_df['predicted'] = test_df.apply(lambda x: predict(train_tree, x), axis=1)
#      22 accuracy = (test_df['predicted'] == test_df['income']).mean()
#      23 print(f"Accuracy: {accuracy:.2f}")
#
# Cell In[19], line 15, in predict(tree, row)
#      13 col = node.split.column
#      14 val = row[col]
# ---> 15 for i, group in enumerate(node.split.groups):
#      16     if val in group:
#      17         node = tree.tree_store[node.children[i]]
#
# AttributeError: 'Split' object has no attribute 'groups'
